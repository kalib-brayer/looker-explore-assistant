# %%
#Convert CSV to JSON
import csv
import json

def csv_to_json(csv_file, json_file):
  """Converts a CSV file to a JSON file.

  Args:
    csv_file: The path to the CSV file.
    json_file: The path to the output JSON file.
  """

  data = []
  with open(csv_file, 'r') as csvfile:
    csvreader = csv.DictReader(csvfile)
    for row in csvreader:
      data.append(dict(row))

  with open(json_file, 'w') as jsonfile:
    json.dump(data, jsonfile, indent=4)


# Example usage
csv_file = '/Users/kalib/Downloads/DMi EA Prompts - Explore Assistant Order Details - Cleansed.csv'
json_file = 'dmi_examples.json'
csv_to_json(csv_file, json_file)
print(f"CSV converted to JSON: {json_file}")
# Out:
# CSV converted to JSON: dmi_examplesv5.json
